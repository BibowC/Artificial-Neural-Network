# %%
import pandas as pd
import numpy as np
import plotly.graph_objs as go
import plotly.offline as pyo 
import CoolProp.CoolProp as CP
import tensorflow as tf
from tensorflow.keras import regularizers
import plotly.io
from sklearn.utils import shuffle

dfV3 = pd.read_excel('Dimensions.xlsx', sheet_name='V3')

Vf_cs4V3 = dfV3.iloc[0,1]
Vf_cs6V3 = dfV3.iloc[0,2]
Vf_cs8V3 = dfV3.iloc[0,3]
Vf_cs10V3 = dfV3.iloc[0,4]
Vf_cs12V3 = dfV3.iloc[0,5]
Vf_cs15V3 = dfV3.iloc[0,6]
Afs_cs4V3 = dfV3.iloc[1,1]
Afs_cs6V3 = dfV3.iloc[1,2]
Afs_cs8V3 = dfV3.iloc[1,3]
Afs_cs10V3 = dfV3.iloc[1,4]
Afs_cs12V3 = dfV3.iloc[1,5]
Afs_cs15V3 = dfV3.iloc[1,6]
Acs_cs4V3 = dfV3.iloc[2,1]
Acs_cs6V3 = dfV3.iloc[2,2]
Acs_cs8V3 = dfV3.iloc[2,3]
Acs_cs10V3 = dfV3.iloc[2,4]
Acs_cs12V3 = dfV3.iloc[2,5]
Acs_cs15V3 = dfV3.iloc[2,6]
Dh_cs4V3 = dfV3.iloc[3,1]
Dh_cs6V3 = dfV3.iloc[3,2]
Dh_cs8V3 = dfV3.iloc[3,3]
Dh_cs10V3 = dfV3.iloc[3,4]
Dh_cs12V3 = dfV3.iloc[3,5]
Dh_cs15V3 = dfV3.iloc[3,6]

Lf = 120/1000

# DEFINING REYNOLDS AND VELOCITY
T = 300
mu = CP.PropsSI('V', 'T', T, 'P', 101325, 'Water')
rho = CP.PropsSI('D', 'T', 300, 'P', 101325, 'Water')

# %%
#FORMULAS DEF (VEL, REYNOLDS, F)

def Reynolds2(mfr, dh, acs, mu):
    Re = (mfr * dh) / (acs * mu)
    return Re 

def Velocity(mfr, rho, acs):
    Vel = (mfr) / (rho * acs)
    return Vel

def ffactor(dp, dh, L, rho, V):
    f = (dp * dh) / (2*L*rho*(np.power(V,2)))
    return f

# %%
Cs4 = pd.read_excel('V3inv.xlsx', sheet_name= 'Cs4')
mfr_cs4_V3 = Cs4.iloc[:,9].values
dP_cs4_V3 = Cs4.iloc[:,7].values * 100000
dh_cs4_V3 = [Dh_cs4V3] * len(dP_cs4_V3)
Re_Cs4_V3 = Reynolds2(mfr_cs4_V3, dh_cs4_V3, Acs_cs4V3, mu)
Vel_Cs4_V3 = Velocity(mfr_cs4_V3, rho, Acs_cs4V3)
f_Cs4_V3 = ffactor(dP_cs4_V3, dh_cs4_V3, Lf, rho, Vel_Cs4_V3)

Cs6 = pd.read_excel('V3inv.xlsx', sheet_name= 'Cs6')
mfr_cs6_V3 = Cs6.iloc[:,9].values
dP_cs6_V3 = Cs6.iloc[:,7].values * 100000
dh_cs6_V3 = [Dh_cs6V3] * len(dP_cs6_V3)
Re_Cs6_V3 = Reynolds2(mfr_cs6_V3, dh_cs6_V3, Acs_cs6V3, mu)
Vel_Cs6_V3 = Velocity(mfr_cs6_V3, rho, Acs_cs6V3)
f_Cs6_V3 = ffactor(dP_cs6_V3, dh_cs6_V3, Lf, rho, Vel_Cs6_V3)

Cs8 = pd.read_excel('V3inv.xlsx', sheet_name= 'Cs8')
mfr_cs8_V3 = Cs8.iloc[:,9].values
dP_cs8_V3 = Cs8.iloc[:,7].values * 100000
dh_cs8_V3 = [Dh_cs8V3] * len(dP_cs8_V3)
Re_Cs8_V3 = Reynolds2(mfr_cs8_V3, dh_cs8_V3, Acs_cs8V3, mu)
Vel_Cs8_V3 = Velocity(mfr_cs8_V3, rho, Acs_cs8V3)
f_Cs8_V3 = ffactor(dP_cs8_V3, dh_cs8_V3, Lf, rho, Vel_Cs8_V3)

'''Cs10 = pd.read_excel('V3inv.xlsx', sheet_name= 'Cs10')
mfr_cs10_V3 = Cs10.iloc[:,9].values
dP_cs10_V3 = Cs10.iloc[:,7].values * 100000
dh_cs10_V3 = [Dh_cs10V3] * len(dP_cs10_V3)
Re_Cs10_V3 = Reynolds2(mfr_cs10_V3, dh_cs10_V3, Acs_cs10V3, mu)
Vel_Cs10_V3 = Velocity(mfr_cs10_V3, rho, Acs_cs10V3)
f_Cs10_V3 = ffactor(dP_cs10_V3, dh_cs10_V3, Lf, rho, Vel_Cs10_V3)'''

Cs12 = pd.read_excel('V3inv.xlsx', sheet_name= 'Cs12')
mfr_cs12_V3 = Cs12.iloc[:,9].values
dP_cs12_V3 = Cs12.iloc[:,7].values * 100000
dh_cs12_V3 = [Dh_cs12V3] * len(dP_cs12_V3)
Re_Cs12_V3 = Reynolds2(mfr_cs12_V3, dh_cs12_V3, Acs_cs12V3, mu)
Vel_Cs12_V3 = Velocity(mfr_cs12_V3, rho, Acs_cs12V3)
f_Cs12_V3 = ffactor(dP_cs12_V3, dh_cs12_V3, Lf, rho, Vel_Cs12_V3)

'''Cs15 = pd.read_excel('V3inv.xlsx', sheet_name= 'Cs15')
mfr_cs15_V3 = Cs15.iloc[:,9].values
dP_cs15_V3 = Cs15.iloc[:,7].values * 100000
dh_cs15_V3 = [Dh_cs15V3] * len(dP_cs15_V3)
Re_Cs15_V3 = Reynolds2(mfr_cs15_V3, dh_cs15_V3, Acs_cs15V3, mu)
Vel_Cs15_V3 = Velocity(mfr_cs15_V3, rho, Acs_cs15V3)
f_Cs15_V3 = ffactor(dP_cs15_V3, dh_cs15_V3, Lf, rho, Vel_Cs15_V3)'''
# Out:
# "Cs15 = pd.read_excel('V3inv.xlsx', sheet_name= 'Cs15')\nmfr_cs15_V3 = Cs15.iloc[:,9].values\ndP_cs15_V3 = Cs15.iloc[:,7].values * 100000\ndh_cs15_V3 = [Dh_cs15V3] * len(dP_cs15_V3)\nRe_Cs15_V3 = Reynolds2(mfr_cs15_V3, dh_cs15_V3, Acs_cs15V3, mu)\nVel_Cs15_V3 = Velocity(mfr_cs15_V3, rho, Acs_cs15V3)\nf_Cs15_V3 = ffactor(dP_cs15_V3, dh_cs15_V3, Lf, rho, Vel_Cs15_V3)"

# %%
print((f_Cs12_V3).max())
print((f_Cs8_V3).max())
print((f_Cs6_V3).max())
print((f_Cs4_V3).max())
# Out:
# 1.7178238574671327
# 4.776775533205177
# 6.571629958193429
# 6.527208560169359

# %%
#DATA REDUCTION

ANNDF = []
stpcs4 = [0.2495] * len(Re_Cs4_V3)
stpcs6 = [0.3326] * len(Re_Cs6_V3)
stpcs8 = [0.3745] * len(Re_Cs8_V3)
stpcs12 = [0.4162] * len(Re_Cs12_V3)

'''Re_Cs4_V3 = np.array(Re_Cs4_V3).flatten()
f_Cs4_V3 = np.array(f_Cs4_V3[0]).flatten()
stpcs4 = [0.2495] * len(Re_Cs4_V3)

Re_Cs6_V3 = np.array(Re_Cs6_V3[0]).flatten()
f_Cs6_V3 = np.array(f_Cs6_V3[0]).flatten()
stpcs6 = [0.3326] * len(Re_Cs6_V3)

Re_Cs8_V3 = np.array(Re_Cs8_V3[0]).flatten()
f_Cs8_V3 = np.array(f_Cs8_V3[0]).flatten()
stpcs8 = [0.3745] * len(Re_Cs8_V3)

Re_Cs10_V3 = np.array(Re_Cs10_V3[0]).flatten()
f_Cs10_V3 = np.array(f_Cs10_V3[0]).flatten()
stpcs10 = [0.3996] * len(Re_Cs10_V3)

Re_Cs12_V3 = np.array(Re_Cs12_V3[0]).flatten()
f_Cs12_V3 = np.array(f_Cs12_V3[0]).flatten()
stpcs12 = [0.4162] * len(Re_Cs12_V3)

Re_Cs15_V3 = np.array(Re_Cs15_V3[0]).flatten()
f_Cs15_V3 = np.array(f_Cs15_V3[0]).flatten()
stpcs15 = [0.4331] * len(Re_Cs15_V3)

'''

# Adicione os dados de cada conjunto no formato DataFrame
ANNDF.append(pd.DataFrame({'Re': Re_Cs4_V3, 'f': f_Cs4_V3, 'stp': stpcs4}))
ANNDF.append(pd.DataFrame({'Re': Re_Cs6_V3, 'f': f_Cs6_V3, 'stp': stpcs6}))
ANNDF.append(pd.DataFrame({'Re': Re_Cs8_V3, 'f': f_Cs8_V3, 'stp': stpcs8}))
#ANNDF.append(pd.DataFrame({'Re': Re_Cs10_V3, 'f': f_Cs10_V3, 'stp': stpcs10}))
ANNDF.append(pd.DataFrame({'Re': Re_Cs12_V3, 'f': f_Cs12_V3, 'stp': stpcs12}))
#ANNDF.append(pd.DataFrame({'Re': Re_Cs15_V3, 'f': f_Cs15_V3, 'stp': stpcs15}))

# Combine todos os DataFrames em um único DataFrame
ANNDF = pd.concat(ANNDF, ignore_index=True)
x = ANNDF.iloc[:,1]

# Exiba o DataFrame combinado
print(x)
# Out:
# 0       1.549400
# 1       1.514248
# 2       1.425212
# 3       1.390088
# 4       1.598329
#           ...
# 2821    1.155492
# 2822    0.893298
# 2823    0.882023
# 2824    1.047430
# 2825    1.199229
# Name: f, Length: 2826, dtype: float64

# %%
# DATA READ - REYNOLDS AND VELOCITY VALUES


#import data, X = inputs, Y = outputs 
ANNDF = shuffle(ANNDF)#embaralha os dados

X = ANNDF.iloc[:,[0,2]].values
Y = ANNDF.iloc[:, 1].values.reshape(-1,1)

# %%
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import make_scorer, r2_score, mean_squared_error

# Função para construir o modelo MLPRegressor
def build_model(hidden_layers_quantity=2, neurons=3, activation_function='relu'):
    hidden_layer_sizes = tuple([neurons] * hidden_layers_quantity)
    model = MLPRegressor(hidden_layer_sizes=hidden_layer_sizes, activation=activation_function, max_iter=epochs, batch_size=batchsize, random_state=1)
    return model

# Definindo os hiperparâmetros para o GridSearchCV
param_grid = {
    'hidden_layer_sizes': [(neurons,) * i for i in range(1, hidden_layers_quantity+1)],
    'activation': ['relu', 'tanh', 'logistic'],
    'solver': ['adam', 'sgd'],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate': ['constant', 'adaptive'],
}

# Aplicando GridSearchCV
mlp = MLPRegressor(max_iter=epochs, batch_size=batchsize)
grid_search = GridSearchCV(estimator=mlp, param_grid=param_grid, cv=kf, scoring='r2', n_jobs=-1)
grid_search.fit(X_scaled, Y_scaled.ravel())

# Resultados do melhor modelo
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print(f"Melhores parâmetros: {best_params}")
print(f"Melhor R²: {best_score}")

# Treinando com os melhores parâmetros
best_model = grid_search.best_estimator_
Y_pred = best_model.predict(X_scaled)

# Avaliação do modelo
r2 = r2_score(Y_scaled, Y_pred)
mse = mean_squared_error(Y_scaled, Y_pred)

print(f"R² final: {r2}")
print(f"MSE final: {mse}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 3
#       1 import numpy as np
#       2 from sklearn.model_selection import GridSearchCV
# ----> 3 from sklearn.neural_network import MLPRegressor
#       4 from sklearn.metrics import make_scorer, r2_score, mean_squared_error
#       6 # Função para construir o modelo MLPRegressor
#
# File c:\Users\Carlos\anaconda3\Lib\site-packages\sklearn\neural_network\__init__.py:5
#       1 """Models based on neural networks."""
#       3 # License: BSD 3 clause
# ----> 5 from ._multilayer_perceptron import MLPClassifier, MLPRegressor
#       6 from ._rbm import BernoulliRBM
#       8 __all__ = ["BernoulliRBM", "MLPClassifier", "MLPRegressor"]
#
# File c:\Users\Carlos\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:16
#      13 import numpy as np
#      14 import scipy.optimize
# ---> 16 from ..base import (
#      17     BaseEstimator,
#      18     ClassifierMixin,
#      19     RegressorMixin,
#      20     _fit_context,
#      21     is_classifier,
#      22 )
#      23 from ..exceptions import ConvergenceWarning
#      24 from ..metrics import accuracy_score, r2_score
#
# ImportError: cannot import name '_fit_context' from 'sklearn.base' (c:\Users\Carlos\anaconda3\Lib\site-packages\sklearn\base.py)

# %%
# RMSE: 0, R2:1
for result in resultados:
    print(f"FOLD{result[0]} -  Para {result[1]} neurônios e {result[2]} camadas, RMSE = {result[3]}, R2 = {result[4]}")
# Out:
# FOLD1 -  Para 1 neurônios e 1 camadas, RMSE = 0.45921574448490726, R2 = 0.7923280173520182
# FOLD1 -  Para 1 neurônios e 2 camadas, RMSE = 1.0094092970190087, R2 = -0.003411260821025275
# FOLD1 -  Para 2 neurônios e 1 camadas, RMSE = 0.37722364368670647, R2 = 0.8598664315942788
# FOLD1 -  Para 2 neurônios e 2 camadas, RMSE = 0.8169990166221586, R2 = 0.3426639702953729
# FOLD1 -  Para 3 neurônios e 1 camadas, RMSE = 0.32366806123030606, R2 = 0.8968322254106165
# FOLD1 -  Para 3 neurônios e 2 camadas, RMSE = 0.5588705812174596, R2 = 0.6924137849934926
# FOLD2 -  Para 1 neurônios e 1 camadas, RMSE = 0.8143759701906167, R2 = 0.4294710866422813
# FOLD2 -  Para 1 neurônios e 2 camadas, RMSE = 1.0781691458872864, R2 = -3.583937262296999e-06
# FOLD2 -  Para 2 neurônios e 1 camadas, RMSE = 0.5085618074350833, R2 = 0.777507568872227
# FOLD2 -  Para 2 neurônios e 2 camadas, RMSE = 0.8864822723943158, R2 = 0.3239670439819806
# FOLD2 -  Para 3 neurônios e 1 camadas, RMSE = 0.5071852462008472, R2 = 0.7787104116475081
# FOLD2 -  Para 3 neurônios e 2 camadas, RMSE = 0.7587486342862249, R2 = 0.5047510055589177
# FOLD3 -  Para 1 neurônios e 1 camadas, RMSE = 0.5109200973778921, R2 = 0.7821981522568365
# FOLD3 -  Para 1 neurônios e 2 camadas, RMSE = 0.644122438871753, R2 = 0.6538275955876256
# FOLD3 -  Para 2 neurônios e 1 camadas, RMSE = 0.42930794600238315, R2 = 0.846222271694562
# FOLD3 -  Para 2 neurônios e 2 camadas, RMSE = 1.1004416175387075, R2 = -0.01039130552240941
# FOLD3 -  Para 3 neurônios e 1 camadas, RMSE = 0.4373422886103545, R2 = 0.8404126240451768
# FOLD3 -  Para 3 neurônios e 2 camadas, RMSE = 0.7953494950159951, R2 = 0.47219730115393066
# FOLD4 -  Para 1 neurônios e 1 camadas, RMSE = 0.37788530036586976, R2 = 0.8151802552686972
# FOLD4 -  Para 1 neurônios e 2 camadas, RMSE = 0.8846022430590019, R2 = -0.01280174741946416
# FOLD4 -  Para 2 neurônios e 1 camadas, RMSE = 0.505062336901422, R2 = 0.669844651526293
# FOLD4 -  Para 2 neurônios e 2 camadas, RMSE = 0.4328795489952745, R2 = 0.7574716532313702
# FOLD4 -  Para 3 neurônios e 1 camadas, RMSE = 0.2934310351331751, R2 = 0.8885601648901024
# FOLD4 -  Para 3 neurônios e 2 camadas, RMSE = 0.5402349928370349, R2 = 0.6222592898935828
# FOLD5 -  Para 1 neurônios e 1 camadas, RMSE = 0.6231479496827679, R2 = 0.5191340305032541
# FOLD5 -  Para 1 neurônios e 2 camadas, RMSE = 0.9061474313371932, R2 = -0.0168091133792998
# FOLD5 -  Para 2 neurônios e 1 camadas, RMSE = 0.5681356879402563, R2 = 0.6002892356763314
# FOLD5 -  Para 2 neurônios e 2 camadas, RMSE = 0.4237160271622408, R2 = 0.7776733695872027
# FOLD5 -  Para 3 neurônios e 1 camadas, RMSE = 0.3353147619179068, R2 = 0.8607654392202868
# FOLD5 -  Para 3 neurônios e 2 camadas, RMSE = 0.3660283011919175, R2 = 0.8340905838311634
# FOLD6 -  Para 1 neurônios e 1 camadas, RMSE = 1.0094588054806146, R2 = -0.0003332772379831539
# FOLD6 -  Para 1 neurônios e 2 camadas, RMSE = 1.009446005103751, R2 = -0.00030790807643987783
# FOLD6 -  Para 2 neurônios e 1 camadas, RMSE = 0.734297600899618, R2 = 0.47068800792871734
# FOLD6 -  Para 2 neurônios e 2 camadas, RMSE = 1.009476618414212, R2 = -0.0003685813580958097
# FOLD6 -  Para 3 neurônios e 1 camadas, RMSE = 0.3637720491868413, R2 = 0.870094910051095
# FOLD6 -  Para 3 neurônios e 2 camadas, RMSE = 0.4480046212057173, R2 = 0.8029699341403559
# FOLD7 -  Para 1 neurônios e 1 camadas, RMSE = 0.7284411915846245, R2 = 0.47309218563149125
# FOLD7 -  Para 1 neurônios e 2 camadas, RMSE = 0.8057697301241047, R2 = 0.3552853421447657
# FOLD7 -  Para 2 neurônios e 1 camadas, RMSE = 1.0044122386450969, R2 = -0.001773730584461175
# FOLD7 -  Para 2 neurônios e 2 camadas, RMSE = 0.802365339692772, R2 = 0.3607216936717481
# FOLD7 -  Para 3 neurônios e 1 camadas, RMSE = 0.4282919865230519, R2 = 0.8178515228775036
# FOLD7 -  Para 3 neurônios e 2 camadas, RMSE = 0.7234266245489136, R2 = 0.4803216507546493
# FOLD8 -  Para 1 neurônios e 1 camadas, RMSE = 0.4177565501400464, R2 = 0.8014263402975857
# FOLD8 -  Para 1 neurônios e 2 camadas, RMSE = 0.7222108331292126, R2 = 0.4065240820535292
# FOLD8 -  Para 2 neurônios e 1 camadas, RMSE = 0.5855806126206108, R2 = 0.6098348427752374
# FOLD8 -  Para 2 neurônios e 2 camadas, RMSE = 0.7127497279664126, R2 = 0.4219715370463877
# FOLD8 -  Para 3 neurônios e 1 camadas, RMSE = 0.3208850244380543, R2 = 0.8828414461660623
# FOLD8 -  Para 3 neurônios e 2 camadas, RMSE = 0.537363808881128, R2 = 0.671442087149034
# FOLD9 -  Para 1 neurônios e 1 camadas, RMSE = 0.5443126895627559, R2 = 0.7423039142708329
# FOLD9 -  Para 1 neurônios e 2 camadas, RMSE = 1.074659467127326, R2 = -0.004506245831278788
# FOLD9 -  Para 2 neurônios e 1 camadas, RMSE = 0.4887314392074326, R2 = 0.7922450126541402
# FOLD9 -  Para 2 neurônios e 2 camadas, RMSE = 0.6946942273897673, R2 = 0.580242674782131
# FOLD9 -  Para 3 neurônios e 1 camadas, RMSE = 0.45414748260773097, R2 = 0.8206073166921435
# FOLD9 -  Para 3 neurônios e 2 camadas, RMSE = 0.8344207797066002, R2 = 0.3944066112791448
# FOLD10 -  Para 1 neurônios e 1 camadas, RMSE = 0.9753775205888162, R2 = -0.001981015721667756
# FOLD10 -  Para 1 neurônios e 2 camadas, RMSE = 0.7636267655510934, R2 = 0.38584740223675185
# FOLD10 -  Para 2 neurônios e 1 camadas, RMSE = 0.33871687031781184, R2 = 0.8791664139606439
# FOLD10 -  Para 2 neurônios e 2 camadas, RMSE = 0.6980566533278392, R2 = 0.4867897161849798
# FOLD10 -  Para 3 neurônios e 1 camadas, RMSE = 0.41369044796316823, R2 = 0.8197542658487251
# FOLD10 -  Para 3 neurônios e 2 camadas, RMSE = 0.41378225028665927, R2 = 0.8196742600702437

# %%
#apply inverse transform on the Xtest and Ytest
Xtest_original = scalerx.inverse_transform(Xtest)
Ytest_original = scalery.inverse_transform(Ytest)

#predict function
Qpred = ann.predict(Xtest)
Qpred_original = scalery.inverse_transform(Qpred)

print(Xtest_original)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/
scatter = go.Scatter3d(x= x, y= y, z= z, mode = 'markers', marker=dict(size = 5, color = z, colorscale = 'Viridis', opacity = 0.8))
layout = go.Layout(
    title='Gráfico de Dispersão 3D',
    scene=dict(
        xaxis_title='Reynolds',
        yaxis_title='Standard Porosity',
        zaxis_title='f'
    )
)
fig = go.Figure( data = [scatter], layout=layout)
pyo.plot(fig)
# Out:
# [1.4987683  0.9403229  1.5716075  2.5655365  1.0115423  1.040541
#  1.0820109  1.0820109  1.0626913  1.0820109  2.1635725  1.5403229
#  1.8742802  1.0783573  0.81953734 0.90724564 1.3430493  1.6166753
#  1.4339736  0.7707406  0.756374   1.789348   1.0409236  0.98762465
#  0.8225164  1.6574217  1.7161323  1.0820109  1.0267572  1.3550873
#  1.4015757  2.0046506  1.6555482  1.0820109  0.678292   1.0438083
#  1.6403079  1.8969477  1.0127698  0.69927007 2.0845754  2.023534
#  0.8162955  1.8217391  0.92961067 2.6060553  1.6538118  1.2563512
#  0.849269   1.007449   1.0560164  0.73202044 0.9132355  0.9616357
#  0.6836202  1.6194855  1.0422692  1.5507551  1.3124218  1.8493854
#  0.91808945 1.347122   0.9964423  0.8691033  1.5283915  1.3984079
#  1.201866   2.730308   1.0745162  2.0122502  0.8552565  2.9570415
#  0.91768765 1.4419651  0.99539036 1.0820109  1.0675843  2.4971285
#  1.4375317  1.0820109  1.538578   1.0263903  0.983646   1.5036861
#  0.9867637  0.87359464 1.6455958  1.0555809  2.6939335  0.7062163
#  1.5058978  0.9228755  1.0376683  1.0630733  1.9618055  1.3124286
#  0.9303593  0.9175036  1.0820109  0.9210465  2.046294   0.73740447
#  1.3802866  0.72270304 2.833907   1.7059702  0.70917326 2.0093675
#  2.2292845  1.9486746  1.0431603  1.047052   0.88843554 1.0348917
#  0.9790152  1.8649774  1.6601148  1.6684972  0.6726569  1.5380168
#  0.7300956  2.1514044  1.0291498  1.5786414  0.790045   0.99776983
#  2.5423827  1.0787308  1.0419419  1.5150603  1.6145011  0.6837597
#  0.6500051  0.9547174  2.436087   1.3963169  0.7160916  1.8569849
#  0.82095414 0.93265134 1.0496806  2.0053058  0.97206897 0.848181
#  0.9356355  1.0746208  0.8837567  0.69232386 0.9477712  0.8684359
#  1.5366344  0.7914398  0.70440304 1.646891   0.97472906 2.708141
#  1.0119305  0.8958281  1.5163484  0.85951716 1.0820109  1.5437559
#  1.0313574  1.5327413  0.92656225 1.0002743  1.8344483  1.9857831
#  1.0820109  1.0053895  1.3439174  1.5560781  1.043906   1.0165007
#  0.82826304 0.87482214 1.5331216  1.0820109  0.9705905  1.0155315
#  0.84799343 0.9936294  2.4687128  1.0190744  0.74739134 1.1831188
#  1.0053531  1.2344358  1.0820109  1.4462246  1.0820109  0.94395816
#  1.7025056  1.0259935  1.0869293  0.9934097  1.0820109  2.562186
#  1.8582952  1.3306309  0.86384404 1.5288597  0.7635434  0.82620436
#  1.0959795  2.2566476  0.89116937 0.9123707  1.0074048  1.0368985
#  0.9834217  1.0433005  1.0444044  1.0820109  1.0820109  1.0200787
#  1.8903965  0.95965505 0.722173   1.0701473  0.856868   0.78187126
#  0.9934307  1.0820109  1.704078   2.2445445  1.4759363  0.97541654
#  1.0306069  0.8462053  0.85624313 1.3014762  0.82869893 0.9328745
#  1.0624913  1.012184   0.9126775  1.0663648  1.376412   0.9661446
#  1.498687   1.0213562  0.7517153  1.021864   0.8380825  0.87503666
#  0.71293926 1.037632   1.0333     0.79155135 1.5822417  1.0768031
#  0.86214423 1.9000924  0.7605584  0.89494926 1.9344211  0.94338423
#  0.8554341  0.99274635 1.5733529  0.82067513 1.1473604  1.0002521
#  1.5391984  1.0315561  0.86276233 0.9801868  2.1882396  2.1201863
#  0.96681845 0.97725683 1.0505072  0.837971   1.0449243  0.9235013
#  1.8230895  2.6655176  0.9431125  1.0820109  0.9012851  1.4435031 ]
# 'temp-plot.html'

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error
from sklearn.utils import shuffle
import plotly.graph_objects as go
from scipy.interpolate import griddata

# Load your dataset
# ANNDF = pd.read_csv('your_dataset.csv')  # Replace with your actual file path

# Shuffle the dataset
ANNDF = shuffle(ANNDF)

# Select inputs (X) and outputs (Y)
X = ANNDF.iloc[:, [0, 2]].values  # Assuming columns 0 and 2 are Reynolds and Velocity
Y = ANNDF.iloc[:, 1].values.reshape(-1, 1)  # Assuming column 1 is the output

# Normalize the data
scalerx = StandardScaler()
scalery = StandardScaler()
X_scaled = scalerx.fit_transform(X)
Y_scaled = scalery.fit_transform(Y)

# Define K-Fold Cross-Validation
kf = KFold(n_splits=10, shuffle=True, random_state=42)

# Define the ANN model
mlp = MLPRegressor(max_iter=1000)

# Define a grid of hyperparameters to search over
parameter_space = {
    'hidden_layer_sizes': [(50,), (100,), (50, 50)],  # Example configurations
    'activation': ['tanh', 'relu'],
    'solver': ['adam', 'sgd'],
    'alpha': [0.0001, 0.05],
    'learning_rate': ['constant', 'adaptive'],
}

# Apply GridSearchCV to find the best parameters
grid_search = GridSearchCV(mlp, parameter_space, n_jobs=-1, cv=kf, scoring='neg_mean_squared_error')
grid_search.fit(X_scaled, Y_scaled.ravel())

# Get the best model
best_mlp = grid_search.best_estimator_
print(f"Best Parameters: {grid_search.best_params_}")

# Predict using the best model
Y_pred_scaled = best_mlp.predict(X_scaled)
Y_pred = scalery.inverse_transform(Y_pred_scaled.reshape(-1, 1))

# Calculate Mean Squared Error
mse = mean_squared_error(scalery.inverse_transform(Y_scaled), Y_pred)
print(f"Mean Squared Error: {mse}")

# Prepare data for Plotly
X_plot = scalerx.inverse_transform(X_scaled)
X1 = X_plot[:, 0]
X2 = X_plot[:, 1]
Y_true = scalery.inverse_transform(Y_scaled).flatten()
Y_pred = Y_pred.flatten()

# Create grid for plotting
grid_x, grid_y = np.mgrid[X1.min():X1.max():100j, X2.min():X2.max():100j]
grid_z = griddata((X1, X2), Y_pred, (grid_x, grid_y), method='linear')

# Create a 3D surface plot using Plotly
fig = go.Figure()

# Add true values scatter plot
fig.add_trace(go.Scatter3d(
    x=X1, y=X2, z=Y_true,
    mode='markers',
    marker=dict(size=5, color='blue', opacity=0.8),
    name='True Values'
))

# Add predicted surface plot
fig.add_trace(go.Surface(
    x=grid_x, y=grid_y, z=grid_z,
    colorscale='Viridis',
    opacity=0.7,
    name='Predicted Surface'
))

fig.update_layout(
    title='3D Surface Plot',
    scene=dict(
        xaxis_title='Reynolds Number',
        yaxis_title='Standard Porosity',
        zaxis_title='f factor'
    )
)
# Out:
# Best Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# Mean Squared Error: 0.0362913290064367

# %%
pyo.plot(fig)
# Out:
# 'temp-plot.html'
