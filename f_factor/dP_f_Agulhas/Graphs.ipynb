# %%
import pandas as pd
import numpy as np
import plotly.graph_objs as go
import plotly.offline as pyo 
import CoolProp.CoolProp as CP

dfv1 = pd.read_excel('Dimensions.xlsx', sheet_name='V1')
dfV2 = pd.read_excel('Dimensions.xlsx', sheet_name='V1')
dfV3 = pd.read_excel('Dimensions.xlsx', sheet_name='V3')
dfV4 = pd.read_excel('Dimensions.xlsx', sheet_name='V4')

stdp = dfv1.iloc[5,1:]

Vf_cs4V1 = dfv1.iloc[0,1]
Vf_cs6V1 = dfv1.iloc[0,2]
Vf_cs8V1 = dfv1.iloc[0,3]
Vf_cs10V1 = dfv1.iloc[0,4]
Vf_cs12V1 = dfv1.iloc[0,5]
Vf_cs15V1 = dfv1.iloc[0,6]
Afs_cs4V1 = dfv1.iloc[1,1]
Afs_cs6V1 = dfv1.iloc[1,2]
Afs_cs8V1 = dfv1.iloc[1,3]
Afs_cs10V1 = dfv1.iloc[1,4]
Afs_cs12V1 = dfv1.iloc[1,5]
Afs_cs15V1 = dfv1.iloc[1,6]
Acs_cs4V1 = dfv1.iloc[2,1]
Acs_cs6V1 = dfv1.iloc[2,2]
Acs_cs8V1 = dfv1.iloc[2,3]
Acs_cs10V1 = dfv1.iloc[2,4]
Acs_cs12V1 = dfv1.iloc[2,5]
Acs_cs15V1 = dfv1.iloc[2,6]
Dh_cs4V1 = dfv1.iloc[3,1]
Dh_cs6V1 = dfv1.iloc[3,2]
Dh_cs8V1 = dfv1.iloc[3,3]
Dh_cs10V1 = dfv1.iloc[3,4]
Dh_cs12V1 = dfv1.iloc[3,5]
Dh_cs15V1 = dfv1.iloc[3,6]

Vf_cs4V2 = dfV2.iloc[0,1]
Vf_cs6V2 = dfV2.iloc[0,2]
Vf_cs8V2 = dfV2.iloc[0,3]
Vf_cs10V2 = dfV2.iloc[0,4]
Vf_cs12V2 = dfV2.iloc[0,5]
Vf_cs15V2 = dfV2.iloc[0,6]
Afs_cs4V2 = dfV2.iloc[1,1]
Afs_cs6V2 = dfV2.iloc[1,2]
Afs_cs8V2 = dfV2.iloc[1,3]
Afs_cs10V2 = dfV2.iloc[1,4]
Afs_cs12V2 = dfV2.iloc[1,5]
Afs_cs15V2 = dfV2.iloc[1,6]
Acs_cs4V2 = dfV2.iloc[2,1]
Acs_cs6V2 = dfV2.iloc[2,2]
Acs_cs8V2 = dfV2.iloc[2,3]
Acs_cs10V2 = dfV2.iloc[2,4]
Acs_cs12V2 = dfV2.iloc[2,5]
Acs_cs15V2 = dfV2.iloc[2,6]
Dh_cs4V2 = dfV2.iloc[3,1]
Dh_cs6V2 = dfV2.iloc[3,2]
Dh_cs8V2 = dfV2.iloc[3,3]
Dh_cs10V2 = dfV2.iloc[3,4]
Dh_cs12V2 = dfV2.iloc[3,5]
Dh_cs15V2 = dfV2.iloc[3,6]

Vf_cs4V3 = dfV3.iloc[0,1]
Vf_cs6V3 = dfV3.iloc[0,2]
Vf_cs8V3 = dfV3.iloc[0,3]
Vf_cs10V3 = dfV3.iloc[0,4]
Vf_cs12V3 = dfV3.iloc[0,5]
Vf_cs15V3 = dfV3.iloc[0,6]
Afs_cs4V3 = dfV3.iloc[1,1]
Afs_cs6V3 = dfV3.iloc[1,2]
Afs_cs8V3 = dfV3.iloc[1,3]
Afs_cs10V3 = dfV3.iloc[1,4]
Afs_cs12V3 = dfV3.iloc[1,5]
Afs_cs15V3 = dfV3.iloc[1,6]
Acs_cs4V3 = dfV3.iloc[2,1]
Acs_cs6V3 = dfV3.iloc[2,2]
Acs_cs8V3 = dfV3.iloc[2,3]
Acs_cs10V3 = dfV3.iloc[2,4]
Acs_cs12V3 = dfV3.iloc[2,5]
Acs_cs15V3 = dfV3.iloc[2,6]
Dh_cs4V3 = dfV3.iloc[3,1]
Dh_cs6V3 = dfV3.iloc[3,2]
Dh_cs8V3 = dfV3.iloc[3,3]
Dh_cs10V3 = dfV3.iloc[3,4]
Dh_cs12V3 = dfV3.iloc[3,5]
Dh_cs15V3 = dfV3.iloc[3,6]

Vf_cs4V4 = dfV4.iloc[0,1]
Vf_cs6V4 = dfV4.iloc[0,2]
Vf_cs8V4 = dfV4.iloc[0,3]
Vf_cs10V4 = dfV4.iloc[0,4]
Vf_cs12V4 = dfV4.iloc[0,5]
Vf_cs15V4 = dfV4.iloc[0,6]
Afs_cs4V4 = dfV4.iloc[1,1]
Afs_cs6V4 = dfV4.iloc[1,2]
Afs_cs8V4 = dfV4.iloc[1,3]
Afs_cs10V4 = dfV4.iloc[1,4]
Afs_cs12V4 = dfV4.iloc[1,5]
Afs_cs15V4 = dfV4.iloc[1,6]
Acs_cs4V4 = dfV4.iloc[2,1]
Acs_cs6V4 = dfV4.iloc[2,2]
Acs_cs8V4 = dfV4.iloc[2,3]
Acs_cs10V4 = dfV4.iloc[2,4]
Acs_cs12V4 = dfV4.iloc[2,5]
Acs_cs15V4 = dfV4.iloc[2,6]
Dh_cs4V4 = dfV4.iloc[3,1]
Dh_cs6V4 = dfV4.iloc[3,2]
Dh_cs8V4 = dfV4.iloc[3,3]
Dh_cs10V4 = dfV4.iloc[3,4]
Dh_cs12V4 = dfV4.iloc[3,5]
Dh_cs15V4 = dfV4.iloc[3,6]

Lf = dfv1.iloc[4,1]

# DEFINING REYNOLDS AND VELOCITY
T = 300
mu = CP.PropsSI('V', 'T', T, 'P', 101325, 'Water')
rho = CP.PropsSI('D', 'T', 300, 'P', 101325, 'Water')

# %%
print(stdp)
# Out:
# CS4     0.2495
# CS6     0.3326
# CS8     0.3745
# CS10    0.3996
# CS12    0.4162
# CS15    0.4331
# Name: 5, dtype: object

# %%
#FORMULAS DEF (VEL, REYNOLDS, F)

def Reynolds2(mfr, dh, acs, mu):
    Re = (mfr * dh) / (acs * mu)
    return Re 

def Velocity(mfr, rho, acs):
    Vel = (mfr) / (rho * acs)
    return Vel

def Velocity2(re, mu, rho, dh):
    Vel = (re * mu) / (rho*dh)
    return Vel

def ffactor(dp, dh, L, rho, V):
    dp = np.array(dp)
    f = (dp * dh) / (2*L*rho*(np.power(V,2)))
    return f

# %%
#V1 DATA

#CS4 DATA
col = [9, 8, 7]


df_cs4 = []

for freq in range(30, 55, 5):
    sheetname = f'{freq}'
    df = pd.read_excel('cs4_v1.xlsx', sheetname)
    df = df.iloc[:, col].values
    df_cs4.append(df)

mfr_cs4V1 = []
dp_cs4V1 = []
abs_cs4V1 = []

for df in df_cs4:
    massflowrate_cs4 = df[:, 0]
    differencial_cs4 = df[:, 1] * 100000
    absolute_cs4 = df[:, 2] * 100000
    lastmfr_cs4 = massflowrate_cs4[-100:]
    lastdp_cs4 = differencial_cs4[-100:]
    lastabs_cs4 = absolute_cs4[-100:]        
    
    meanmfr_cs4 = lastmfr_cs4.mean()
    meandp_cs4 = lastdp_cs4.mean()
    meanabs_cs4 = lastabs_cs4.mean() 

    mfr_cs4V1.append(meanmfr_cs4)
    dp_cs4V1.append(meandp_cs4)
    abs_cs4V1.append(meanabs_cs4)

#CS6 DATA

col = [9, 8, 7]

df_cs6 = []

for freq in range(20, 55, 5):
    sheetname = f'{freq}'
    df = pd.read_excel('cs6_v1.xlsx', sheetname)
    df = df.iloc[:, col].values
    df_cs6.append(df)

mfr_cs6V1 = []
dp_cs6V1 = []
abs_cs6V1 = []

for df in df_cs6:
    massflowrate_cs6 = df[:, 0]
    differencial_cs6 = df[:, 1] * 100000
    absolute_cs6 = df[:, 2] * 100000
    lastmfr_cs6 = massflowrate_cs6[-100:]
    lastdp_cs6 = differencial_cs6[-100:]
    lastabs_cs6 = absolute_cs6[-100:]        
    
    meanmfr_cs6 = lastmfr_cs6.mean()
    meandp_cs6 = lastdp_cs6.mean()
    meanabs_cs6 = lastabs_cs6.mean() 

    mfr_cs6V1.append(meanmfr_cs6)
    dp_cs6V1.append(meandp_cs6)
    abs_cs6V1.append(meanabs_cs6)

#CS8 DATA

col = [9, 8, 7]

df_cs8 = []

for freq in range(25, 55, 5):
    sheetname = f'{freq}'
    df = pd.read_excel('cs8_v1.xlsx', sheetname)
    df = df.iloc[:, col].values
    df_cs8.append(df)

mfr_cs8V1 = []
dp_cs8V1= []
abs_cs8V1 = []

for df in df_cs8:
    massflowrate_cs8 = df[:, 0]
    differencial_cs8 = df[:, 1] * 100000
    absolute_cs8 = df[:, 2] * 100000
    lastmfr_cs8 = massflowrate_cs8[-100:]
    lastdp_cs8 = differencial_cs8[-100:]
    lastabs_cs8 = absolute_cs8[-100:]        
    
    meanmfr_cs8 = lastmfr_cs8.mean()
    meandp_cs8 = lastdp_cs8.mean()
    meanabs_cs8 = lastabs_cs8.mean() 

    mfr_cs8V1.append(meanmfr_cs8)
    dp_cs8V1.append(meandp_cs8)
    abs_cs8V1.append(meanabs_cs8)

    #CS10 DATA

col = [9, 8, 7]

df_cs10 = []

for freq in range(25, 55, 5):
    sheetname = f'{freq}'
    df = pd.read_excel('cs10_v1.xlsx', sheetname)
    df = df.iloc[:, col].values
    df_cs10.append(df)

mfr_cs10V1 = []
dp_cs10V1 = []
abs_cs10V1 = []

for df in df_cs10:
    massflowrate_cs10 = df[:, 0]
    differencial_cs10 = df[:, 1] * 100000
    absolute_cs10 = df[:, 2] * 100000
    lastmfr_cs10 = massflowrate_cs10[-100:]
    lastdp_cs10 = differencial_cs10[-100:]
    lastabs_cs10 = absolute_cs10[-100:]        
    
    meanmfr_cs10 = lastmfr_cs10.mean()
    meandp_cs10 = lastdp_cs10.mean()
    meanabs_cs10 = lastabs_cs10.mean() 

    mfr_cs10V1.append(meanmfr_cs10)
    dp_cs10V1.append(meandp_cs10)
    abs_cs10V1.append(meanabs_cs10)

    #CS12 DATA

col = [9, 8, 7]

df_cs12 = []

for freq in range(25, 55, 5):
    sheetname = f'{freq}'
    df = pd.read_excel('cs12_v1.xlsx', sheetname)
    df = df.iloc[:, col].values
    df_cs12.append(df)

mfr_cs12V1 = []
dp_cs12V1 = []
abs_cs12V1 = []

for df in df_cs12:
    massflowrate_cs12 = df[:, 0]
    differencial_cs12 = df[:, 1] * 100000
    absolute_cs12 = df[:, 2] * 100000
    lastmfr_cs12 = massflowrate_cs12[-100:]
    lastdp_cs12 = differencial_cs12[-100:]
    lastabs_cs12 = absolute_cs12[-100:]        
    
    meanmfr_cs12 = lastmfr_cs12.mean()
    meandp_cs12 = lastdp_cs12.mean()
    meanabs_cs12 = lastabs_cs12.mean() 

    mfr_cs12V1.append(meanmfr_cs12)
    dp_cs12V1.append(meandp_cs12)
    abs_cs12V1.append(meanabs_cs12)

    #CS15 DATA

col = [9, 8, 7]

df_cs15 = []

for freq in range(25, 55, 5):
    sheetname = f'{freq}'
    df = pd.read_excel('cs15_v1.xlsx', sheetname)
    df = df.iloc[:, col].values
    df_cs15.append(df)

mfr_cs15V1 = []
dp_cs15V1 = []
abs_cs15V1 = []

for df in df_cs15:
    massflowrate_cs15 = df[:, 0]
    differencial_cs15 = df[:, 1] * 100000
    absolute_cs15 = df[:, 2] * 100000
    lastmfr_cs15 = massflowrate_cs15[-100:]
    lastdp_cs15 = differencial_cs15[-100:]
    lastabs_cs15 = absolute_cs15[-100:]        
    
    meanmfr_cs15 = lastmfr_cs15.mean()
    meandp_cs15 = lastdp_cs15.mean()
    meanabs_cs15 = lastabs_cs15.mean() 

    mfr_cs15V1.append(meanmfr_cs15)
    dp_cs15V1.append(meandp_cs15)
    abs_cs15V1.append(meanabs_cs15)

# %%
#V2 DATA

#CS4 DATA
col = [9, 8, 7]


df_cs4 = []

for freq in range(30, 55, 5):
    sheetname = f'{freq}'
    df = pd.read_excel('cs4_v2.xlsx', sheetname)
    df = df.iloc[:, col].values
    df_cs4.append(df)

mfr_cs4V2 = []
dp_cs4V2 = []
abs_cs4V2 = []

for df in df_cs4:
    massflowrate_cs4 = df[:, 0]
    differencial_cs4 = df[:, 1] * 100000
    absolute_cs4 = df[:, 2] * 100000
    lastmfr_cs4 = massflowrate_cs4[-100:]
    lastdp_cs4 = differencial_cs4[-100:]
    lastabs_cs4 = absolute_cs4[-100:]        
    
    meanmfr_cs4 = lastmfr_cs4.mean()
    meandp_cs4 = lastdp_cs4.mean()
    meanabs_cs4 = lastabs_cs4.mean() 

    mfr_cs4V2.append(meanmfr_cs4)
    dp_cs4V2.append(meandp_cs4)
    abs_cs4V2.append(meanabs_cs4)

#CS6 DATA

col = [9, 8, 7]

df_cs6 = []

for freq in range(20, 55, 5):
    sheetname = f'{freq}'
    df = pd.read_excel('cs6_v2.xlsx', sheetname)
    df = df.iloc[:, col].values
    df_cs6.append(df)

mfr_cs6V2 = []
dp_cs6V2 = []
abs_cs6V2 = []

for df in df_cs6:
    massflowrate_cs6 = df[:, 0]
    differencial_cs6 = df[:, 1] * 100000
    absolute_cs6 = df[:, 2] * 100000
    lastmfr_cs6 = massflowrate_cs6[-100:]
    lastdp_cs6 = differencial_cs6[-100:]
    lastabs_cs6 = absolute_cs6[-100:]        
    
    meanmfr_cs6 = lastmfr_cs6.mean()
    meandp_cs6 = lastdp_cs6.mean()
    meanabs_cs6 = lastabs_cs6.mean() 

    mfr_cs6V2.append(meanmfr_cs6)
    dp_cs6V2.append(meandp_cs6)
    abs_cs6V2.append(meanabs_cs6)

#CS8 DATA

col = [9, 8, 7]

df_cs8 = []

for freq in range(25, 55, 5):
    sheetname = f'{freq}'
    df = pd.read_excel('cs8_v2.xlsx', sheetname)
    df = df.iloc[:, col].values
    df_cs8.append(df)

mfr_cs8V2 = []
dp_cs8V2 = []
abs_cs8V2 = []

for df in df_cs8:
    massflowrate_cs8 = df[:, 0]
    differencial_cs8 = df[:, 1] * 100000
    absolute_cs8 = df[:, 2] * 100000
    lastmfr_cs8 = massflowrate_cs8[-100:]
    lastdp_cs8 = differencial_cs8[-100:]
    lastabs_cs8 = absolute_cs8[-100:]        
    
    meanmfr_cs8 = lastmfr_cs8.mean()
    meandp_cs8 = lastdp_cs8.mean()
    meanabs_cs8 = lastabs_cs8.mean() 

    mfr_cs8V2.append(meanmfr_cs8)
    dp_cs8V2.append(meandp_cs8)
    abs_cs8V2.append(meanabs_cs8)

    #CS10 DATA

col = [9, 8, 7]

df_cs10 = []

for freq in range(25, 55, 5):
    sheetname = f'{freq}'
    df = pd.read_excel('cs10_v2.xlsx', sheetname)
    df = df.iloc[:, col].values
    df_cs10.append(df)

mfr_cs10V2 = []
dp_cs10V2 = []
abs_cs10V2 = []

for df in df_cs10:
    massflowrate_cs10 = df[:, 0]
    differencial_cs10 = df[:, 1] * 100000
    absolute_cs10 = df[:, 2] * 100000
    lastmfr_cs10 = massflowrate_cs10[-100:]
    lastdp_cs10 = differencial_cs10[-100:]
    lastabs_cs10 = absolute_cs10[-100:]        
    
    meanmfr_cs10 = lastmfr_cs10.mean()
    meandp_cs10 = lastdp_cs10.mean()
    meanabs_cs10 = lastabs_cs10.mean() 

    mfr_cs10V2.append(meanmfr_cs10)
    dp_cs10V2.append(meandp_cs10)
    abs_cs10V2.append(meanabs_cs10)

    #CS12 DATA

col = [9, 8, 7]

df_cs12 = []

for freq in range(25, 55, 5):
    sheetname = f'{freq}'
    df = pd.read_excel('cs12_v2.xlsx', sheetname)
    df = df.iloc[:, col].values
    df_cs12.append(df)

mfr_cs12V2 = []
dp_cs12V2 = []
abs_cs12V2 = []

for df in df_cs12:
    massflowrate_cs12 = df[:, 0]
    differencial_cs12 = df[:, 1] * 100000
    absolute_cs12 = df[:, 2] * 100000
    lastmfr_cs12 = massflowrate_cs12[-100:]
    lastdp_cs12 = differencial_cs12[-100:]
    lastabs_cs12 = absolute_cs12[-100:]        
    
    meanmfr_cs12 = lastmfr_cs12.mean()
    meandp_cs12 = lastdp_cs12.mean()
    meanabs_cs12 = lastabs_cs12.mean() 

    mfr_cs12V2.append(meanmfr_cs12)
    dp_cs12V2.append(meandp_cs12)
    abs_cs12V2.append(meanabs_cs12)

#CS15 DATA

col = [9, 8, 7]

df_cs15 = []

for freq in range(25, 55, 5):
    sheetname = f'{freq}'
    df = pd.read_excel('cs15_v2.xlsx', sheetname)
    df = df.iloc[:, col].values
    df_cs15.append(df)

mfr_cs15V2 = []
dp_cs15V2 = []
abs_cs15V2 = []

for df in df_cs15:
    massflowrate_cs15 = df[:, 0]
    differencial_cs15 = df[:, 1] * 100000
    absolute_cs15 = df[:, 2] * 100000
    lastmfr_cs15 = massflowrate_cs15[-100:]
    lastdp_cs15 = differencial_cs15[-100:]
    lastabs_cs15 = absolute_cs15[-100:]        
    
    meanmfr_cs15 = lastmfr_cs15.mean()
    meandp_cs15 = lastdp_cs15.mean()
    meanabs_cs15 = lastabs_cs15.mean() 

    mfr_cs15V2.append(meanmfr_cs15)
    dp_cs15V2.append(meandp_cs15)
    abs_cs15V2.append(meanabs_cs15)

# %%
#V3 DATA

#CS4 DATA
col = [9, 8, 7]


df_cs4 = []

for freq in range(30, 55, 5):
    sheetname = f'{freq}'
    df = pd.read_excel('cs4_v3.xlsx', sheetname)
    df = df.iloc[:, col].values
    df_cs4.append(df)

mfr_cs4V3 = []
dp_cs4V3 = []
abs_cs4V3 = []

for df in df_cs4:
    massflowrate_cs4 = df[:, 0]
    differencial_cs4 = df[:, 1] * 100000
    absolute_cs4 = df[:, 2] * 100000
    lastmfr_cs4 = massflowrate_cs4[-100:]
    lastdp_cs4 = differencial_cs4[-100:]
    lastabs_cs4 = absolute_cs4[-100:]        
    
    meanmfr_cs4 = lastmfr_cs4.mean()
    meandp_cs4 = lastdp_cs4.mean()
    meanabs_cs4 = lastabs_cs4.mean() 

    mfr_cs4V3.append(meanmfr_cs4)
    dp_cs4V3.append(meandp_cs4)
    abs_cs4V3.append(meanabs_cs4)


#CS6 DATA

col = [9, 8, 7]

df_cs6 = []

for freq in range(20, 55, 5):
    sheetname = f'{freq}'
    df = pd.read_excel('cs6_v3.xlsx', sheetname)
    df = df.iloc[:, col].values
    df_cs6.append(df)

mfr_cs6V3= []
dp_cs6V3 = []
abs_cs6V3 = []

for df in df_cs6:
    massflowrate_cs6 = df[:, 0]
    differencial_cs6 = df[:, 1] * 100000
    absolute_cs6 = df[:, 2] * 100000
    lastmfr_cs6 = massflowrate_cs6[-100:]
    lastdp_cs6 = differencial_cs6[-100:]
    lastabs_cs6 = absolute_cs6[-100:]        
    
    meanmfr_cs6 = lastmfr_cs6.mean()
    meandp_cs6 = lastdp_cs6.mean()
    meanabs_cs6 = lastabs_cs6.mean() 

    mfr_cs6V3.append(meanmfr_cs6)
    dp_cs6V3.append(meandp_cs6)
    abs_cs6V3.append(meanabs_cs6)


#CS8 DATA

col = [9, 8, 7]

df_cs8 = []

for freq in range(25, 55, 5):
    sheetname = f'{freq}'
    df = pd.read_excel('cs8_v3.xlsx', sheetname)
    df = df.iloc[:, col].values
    df_cs8.append(df)

mfr_cs8V3 = []
dp_cs8V3 = []
abs_cs8V3 = []

for df in df_cs8:
    massflowrate_cs8 = df[:, 0]
    differencial_cs8 = df[:, 1] * 100000
    absolute_cs8 = df[:, 2] * 100000
    lastmfr_cs8 = massflowrate_cs8[-100:]
    lastdp_cs8 = differencial_cs8[-100:]
    lastabs_cs8 = absolute_cs8[-100:]        
    
    meanmfr_cs8 = lastmfr_cs8.mean()
    meandp_cs8 = lastdp_cs8.mean()
    meanabs_cs8 = lastabs_cs8.mean() 

    mfr_cs8V3.append(meanmfr_cs8)
    dp_cs8V3.append(meandp_cs8)
    abs_cs8V3.append(meanabs_cs8)


    #CS10 DATA

col = [9, 8, 7]

df_cs10 = []

for freq in range(25, 55, 5):
    sheetname = f'{freq}'
    df = pd.read_excel('cs10_v3.xlsx', sheetname)
    df = df.iloc[:, col].values
    df_cs10.append(df)

mfr_cs10V3 = []
dp_cs10V3 = []
abs_cs10V3 = []

for df in df_cs10:
    massflowrate_cs10 = df[:, 0]
    differencial_cs10 = df[:, 1] * 100000
    absolute_cs10 = df[:, 2] * 100000
    lastmfr_cs10 = massflowrate_cs10[-100:]
    lastdp_cs10 = differencial_cs10[-100:]
    lastabs_cs10 = absolute_cs10[-100:]        
    
    meanmfr_cs10 = lastmfr_cs10.mean()
    meandp_cs10 = lastdp_cs10.mean()
    meanabs_cs10 = lastabs_cs10.mean() 

    mfr_cs10V3.append(meanmfr_cs10)
    dp_cs10V3.append(meandp_cs10)
    abs_cs10V3.append(meanabs_cs10)

#CS12 DATA

col = [9, 8, 7]

df_cs12 = []

for freq in range(25, 55, 5):
    sheetname = f'{freq}'
    df = pd.read_excel('cs12_v3.xlsx', sheetname)
    df = df.iloc[:, col].values
    df_cs12.append(df)

mfr_cs12V3 = []
dp_cs12V3 = []
abs_cs12V3 = []

for df in df_cs12:
    massflowrate_cs12 = df[:, 0]
    differencial_cs12 = df[:, 1] * 100000
    absolute_cs12 = df[:, 2] * 100000
    lastmfr_cs12 = massflowrate_cs12[-100:]
    lastdp_cs12 = differencial_cs12[-100:]
    lastabs_cs12 = absolute_cs12[-100:]        
    
    meanmfr_cs12 = lastmfr_cs12.mean()
    meandp_cs12 = lastdp_cs12.mean()
    meanabs_cs12 = lastabs_cs12.mean() 

    mfr_cs12V3.append(meanmfr_cs12)
    dp_cs12V3.append(meandp_cs12)
    abs_cs12V3.append(meanabs_cs12)

#CS15 DATA

col = [9, 8, 7]

df_cs15 = []

for freq in range(25, 55, 5):
    sheetname = f'{freq}'
    df = pd.read_excel('cs15_v3.xlsx', sheetname)
    df = df.iloc[:, col].values
    df_cs15.append(df)

mfr_cs15V3 = []
dp_cs15V3 = []
abs_cs15V3 = []

for df in df_cs15:
    massflowrate_cs15 = df[:, 0]
    differencial_cs15 = df[:, 1] * 100000
    absolute_cs15 = df[:, 2] * 100000
    lastmfr_cs15 = massflowrate_cs15[-100:]
    lastdp_cs15 = differencial_cs15[-100:]
    lastabs_cs15 = absolute_cs15[-100:]        
    
    meanmfr_cs15 = lastmfr_cs15.mean()
    meandp_cs15 = lastdp_cs15.mean()
    meanabs_cs15 = lastabs_cs15.mean() 

    mfr_cs15V3.append(meanmfr_cs15)
    dp_cs15V3.append(meandp_cs15)
    abs_cs15V3.append(meanabs_cs15)

# %%
#V4 DATA

#CS4 DATA
col = [9, 8, 7]


df_cs4 = []

for freq in range(30, 55, 5):
    sheetname = f'{freq}'
    df = pd.read_excel('cs4_V4.xlsx', sheetname)
    df = df.iloc[:, col].values
    df_cs4.append(df)

mfr_cs4V4 = []
dp_cs4V4 = []
abs_cs4V4 = []

for df in df_cs4:
    massflowrate_cs4 = df[:, 0]
    differencial_cs4 = df[:, 1] * 100000
    absolute_cs4 = df[:, 2] * 100000
    lastmfr_cs4 = massflowrate_cs4[-100:]
    lastdp_cs4 = differencial_cs4[-100:]
    lastabs_cs4 = absolute_cs4[-100:]        
    
    meanmfr_cs4 = lastmfr_cs4.mean()
    meandp_cs4 = lastdp_cs4.mean()
    meanabs_cs4 = lastabs_cs4.mean() 

    mfr_cs4V4.append(meanmfr_cs4)
    dp_cs4V4.append(meandp_cs4)
    abs_cs4V4.append(meanabs_cs4)

#CS6 DATA

col = [9, 8, 7]

df_cs6 = []

for freq in range(20, 55, 5):
    sheetname = f'{freq}'
    df = pd.read_excel('cs6_V4.xlsx', sheetname)
    df = df.iloc[:, col].values
    df_cs6.append(df)

mfr_cs6V4 = []
dp_cs6V4 = []
abs_cs6V4 = []

for df in df_cs6:
    massflowrate_cs6 = df[:, 0]
    differencial_cs6 = df[:, 1] * 100000
    absolute_cs6 = df[:, 2] * 100000
    lastmfr_cs6 = massflowrate_cs6[-100:]
    lastdp_cs6 = differencial_cs6[-100:]
    lastabs_cs6 = absolute_cs6[-100:]        
    
    meanmfr_cs6 = lastmfr_cs6.mean()
    meandp_cs6 = lastdp_cs6.mean()
    meanabs_cs6 = lastabs_cs6.mean() 

    mfr_cs6V4.append(meanmfr_cs6)
    dp_cs6V4.append(meandp_cs6)
    abs_cs6V4.append(meanabs_cs6)

#CS8 DATA

col = [9, 8, 7]

df_cs8 = []

for freq in range(25, 55, 5):
    sheetname = f'{freq}'
    df = pd.read_excel('cs8_V4.xlsx', sheetname)
    df = df.iloc[:, col].values
    df_cs8.append(df)

mfr_cs8V4 = []
dp_cs8V4= []
abs_cs8V4 = []

for df in df_cs8:
    massflowrate_cs8 = df[:, 0]
    differencial_cs8 = df[:, 1] * 100000
    absolute_cs8 = df[:, 2] * 100000
    lastmfr_cs8 = massflowrate_cs8[-100:]
    lastdp_cs8 = differencial_cs8[-100:]
    lastabs_cs8 = absolute_cs8[-100:]        
    
    meanmfr_cs8 = lastmfr_cs8.mean()
    meandp_cs8 = lastdp_cs8.mean()
    meanabs_cs8 = lastabs_cs8.mean() 

    mfr_cs8V4.append(meanmfr_cs8)
    dp_cs8V4.append(meandp_cs8)
    abs_cs8V4.append(meanabs_cs8)

    #CS10 DATA

col = [9, 8, 7]

df_cs10 = []

for freq in range(25, 55, 5):
    sheetname = f'{freq}'
    df = pd.read_excel('cs10_V4.xlsx', sheetname)
    df = df.iloc[:, col].values
    df_cs10.append(df)

mfr_cs10V4 = []
dp_cs10V4 = []
abs_cs10V4 = []

for df in df_cs10:
    massflowrate_cs10 = df[:, 0]
    differencial_cs10 = df[:, 1] * 100000
    absolute_cs10 = df[:, 2] * 100000
    lastmfr_cs10 = massflowrate_cs10[-100:]
    lastdp_cs10 = differencial_cs10[-100:]
    lastabs_cs10 = absolute_cs10[-100:]        
    
    meanmfr_cs10 = lastmfr_cs10.mean()
    meandp_cs10 = lastdp_cs10.mean()
    meanabs_cs10 = lastabs_cs10.mean() 

    mfr_cs10V4.append(meanmfr_cs10)
    dp_cs10V4.append(meandp_cs10)
    abs_cs10V4.append(meanabs_cs10)

    #CS12 DATA

col = [9, 8, 7]

df_cs12 = []

for freq in range(25, 55, 5):
    sheetname = f'{freq}'
    df = pd.read_excel('cs12_V4.xlsx', sheetname)
    df = df.iloc[:, col].values
    df_cs12.append(df)

mfr_cs12V4 = []
dp_cs12V4 = []
abs_cs12V4 = []

for df in df_cs12:
    massflowrate_cs12 = df[:, 0]
    differencial_cs12 = df[:, 1] * 100000
    absolute_cs12 = df[:, 2] * 100000
    lastmfr_cs12 = massflowrate_cs12[-100:]
    lastdp_cs12 = differencial_cs12[-100:]
    lastabs_cs12 = absolute_cs12[-100:]        
    
    meanmfr_cs12 = lastmfr_cs12.mean()
    meandp_cs12 = lastdp_cs12.mean()
    meanabs_cs12 = lastabs_cs12.mean() 

    mfr_cs12V4.append(meanmfr_cs12)
    dp_cs12V4.append(meandp_cs12)
    abs_cs12V4.append(meanabs_cs12)

    #CS15 DATA

col = [9, 8, 7]

df_cs15 = []

for freq in range(25, 55, 5):
    sheetname = f'{freq}'
    df = pd.read_excel('cs15_V4.xlsx', sheetname)
    df = df.iloc[:, col].values
    df_cs15.append(df)

mfr_cs15V4 = []
dp_cs15V4 = []
abs_cs15V4 = []

for df in df_cs15:
    massflowrate_cs15 = df[:, 0]
    differencial_cs15 = df[:, 1] * 100000
    absolute_cs15 = df[:, 2] * 100000
    lastmfr_cs15 = massflowrate_cs15[-100:]
    lastdp_cs15 = differencial_cs15[-100:]
    lastabs_cs15 = absolute_cs15[-100:]        
    
    meanmfr_cs15 = lastmfr_cs15.mean()
    meandp_cs15 = lastdp_cs15.mean()
    meanabs_cs15 = lastabs_cs15.mean() 

    mfr_cs15V4.append(meanmfr_cs15)
    dp_cs15V4.append(meandp_cs15)
    abs_cs15V4.append(meanabs_cs15)

# %%
# REYNOLDS AND VELOCITY VALUES V1

mfr_cs4V1 = np.array(mfr_cs4V1)
mfr_cs6V1 = np.array(mfr_cs6V1)
mfr_cs8V1 = np.array(mfr_cs8V1)
mfr_cs10V1 = np.array(mfr_cs10V1)
mfr_cs12V1 = np.array(mfr_cs12V1)
mfr_cs15V1 = np.array(mfr_cs15V1)

V_cs4V1 = np.array(Velocity(mfr_cs4V1, rho, Acs_cs4V1))
V_cs6V1 = np.array(Velocity(mfr_cs6V1, rho, Acs_cs6V1))
V_cs8V1 = np.array(Velocity(mfr_cs8V1, rho, Acs_cs8V1))
V_cs10V1 = np.array(Velocity(mfr_cs10V1, rho, Acs_cs10V1))
V_cs12V1 = np.array(Velocity(mfr_cs12V1, rho, Acs_cs12V1))
V_cs15V1 = np.array(Velocity(mfr_cs15V1, rho, Acs_cs15V1))



Re_cs4_V1 = Reynolds2(mfr_cs4V1, Dh_cs4V1, Acs_cs4V1, mu)
Re_cs6_V1 = Reynolds2(mfr_cs6V1, Dh_cs6V1, Acs_cs6V1, mu)
Re_cs8_V1 = Reynolds2(mfr_cs8V1, Dh_cs8V1, Acs_cs8V1, mu)
Re_cs10_V1 = Reynolds2(mfr_cs10V1, Dh_cs10V1, Acs_cs10V1, mu)
Re_cs12_V1 = Reynolds2(mfr_cs12V1, Dh_cs12V1, Acs_cs12V1, mu)
Re_cs15_V1 = Reynolds2(mfr_cs15V1, Dh_cs15V1, Acs_cs15V1, mu)



f_cs4V1 = ffactor(np.array(abs_cs4V1), Dh_cs4V1, Lf, rho, V_cs4V1)
f_cs6V1 = ffactor(np.array(abs_cs6V1), Dh_cs6V1, Lf, rho, V_cs6V1)
f_cs8V1 = ffactor(np.array(abs_cs8V1), Dh_cs8V1, Lf, rho, V_cs8V1)
f_cs10V1 = ffactor(np.array(abs_cs10V1), Dh_cs10V1, Lf, rho, V_cs10V1)
f_cs12V1 = ffactor(np.array(abs_cs12V1), Dh_cs12V1, Lf, rho, V_cs12V1)
f_cs15V1 = ffactor(np.array(abs_cs15V1), Dh_cs15V1, Lf, rho, V_cs15V1)

# %%
# REYNOLDS AND VELOCITY VALUES V2

mfr_cs4V2 = np.array(mfr_cs4V2)
mfr_cs6V2 = np.array(mfr_cs6V2)
mfr_cs8V2 = np.array(mfr_cs8V2)
mfr_cs10V2 = np.array(mfr_cs10V2)
mfr_cs12V2 = np.array(mfr_cs12V2)
mfr_cs15V2 = np.array(mfr_cs15V2)

V_cs4V2 = np.array(Velocity(mfr_cs4V2, rho, Acs_cs4V2))
V_cs6V2 = np.array(Velocity(mfr_cs6V2, rho, Acs_cs6V2))
V_cs8V2 = np.array(Velocity(mfr_cs8V2, rho, Acs_cs8V2))
V_cs10V2 = np.array(Velocity(mfr_cs10V2, rho, Acs_cs10V2))
V_cs12V2 = np.array(Velocity(mfr_cs12V2, rho, Acs_cs12V2))
V_cs15V2 = np.array(Velocity(mfr_cs15V2, rho, Acs_cs15V2))

Re_cs4_V2 = Reynolds2(mfr_cs4V2, Dh_cs4V2, Acs_cs4V2, mu)
Re_cs6_V2 = Reynolds2(mfr_cs6V2, Dh_cs6V2, Acs_cs6V2, mu)
Re_cs8_V2 = Reynolds2(mfr_cs8V2, Dh_cs8V2, Acs_cs8V2, mu)
Re_cs10_V2 = Reynolds2(mfr_cs10V2, Dh_cs10V2, Acs_cs10V2, mu)
Re_cs12_V2 = Reynolds2(mfr_cs12V2, Dh_cs12V2, Acs_cs12V2, mu)
Re_cs15_V2 = Reynolds2(mfr_cs15V2, Dh_cs15V2, Acs_cs15V2, mu)

f_cs4V2 = ffactor(np.array(abs_cs4V2), Dh_cs4V2, Lf, rho, V_cs4V2)
f_cs6V2 = ffactor(np.array(abs_cs6V2), Dh_cs6V2, Lf, rho, V_cs6V2)
f_cs8V2= ffactor(np.array(abs_cs8V2), Dh_cs8V2, Lf, rho, V_cs8V2)
f_cs10V2 = ffactor(np.array(abs_cs10V2), Dh_cs10V2, Lf, rho, V_cs10V2)
f_cs12V2 = ffactor(np.array(abs_cs12V2), Dh_cs12V2, Lf, rho, V_cs12V2)
f_cs15V2 = ffactor(np.array(abs_cs15V2), Dh_cs15V2, Lf, rho, V_cs15V2)

# %%
# REYNOLDS AND VELOCITY VALUES V3


mfr_cs4V3 = np.array(mfr_cs4V3)
mfr_cs6V3 = np.array(mfr_cs6V3)
mfr_cs8V3 = np.array(mfr_cs8V3)
mfr_cs10V3 = np.array(mfr_cs10V3)
mfr_cs12V3 = np.array(mfr_cs12V3)
mfr_cs15V3 = np.array(mfr_cs15V3)

V_cs4V3 = np.array(Velocity(mfr_cs4V3, rho, Acs_cs4V3))
V_cs6V3 = np.array(Velocity(mfr_cs6V3, rho, Acs_cs6V3))
V_cs8V3 = np.array(Velocity(mfr_cs8V3, rho, Acs_cs8V3))
V_cs10V3 = np.array(Velocity(mfr_cs10V3, rho, Acs_cs10V3))
V_cs12V3 = np.array(Velocity(mfr_cs12V3, rho, Acs_cs12V3))
V_cs15V3 = np.array(Velocity(mfr_cs15V3, rho, Acs_cs15V3))

Re_cs4_V3 = Reynolds2(mfr_cs4V3, Dh_cs4V3, Acs_cs4V3, mu)
Re_cs6_V3 = Reynolds2(mfr_cs6V3, Dh_cs6V3, Acs_cs6V3, mu)
Re_cs8_V3 = Reynolds2(mfr_cs8V3, Dh_cs8V3, Acs_cs8V3, mu)
Re_cs10_V3 = Reynolds2(mfr_cs10V3, Dh_cs10V3, Acs_cs10V3, mu)
Re_cs12_V3 = Reynolds2(mfr_cs12V3, Dh_cs12V3, Acs_cs12V3, mu)
Re_cs15_V3 = Reynolds2(mfr_cs15V3, Dh_cs15V3, Acs_cs15V3, mu)

f_cs4V3 = ffactor(np.array(abs_cs4V3), Dh_cs4V3, Lf, rho, V_cs4V3)
f_cs6V3 = ffactor(np.array(abs_cs6V3), Dh_cs6V3, Lf, rho, V_cs6V3)
f_cs8V3 = ffactor(np.array(abs_cs8V3), Dh_cs8V3, Lf, rho, V_cs8V3)
f_cs10V3 = ffactor(np.array(abs_cs10V3), Dh_cs10V3, Lf, rho, V_cs10V3)
f_cs12V3 = ffactor(np.array(abs_cs12V3), Dh_cs12V3, Lf, rho, V_cs12V3)
f_cs15V3 = ffactor(np.array(abs_cs15V3), Dh_cs15V3, Lf, rho, V_cs15V3)

# %%
# REYNOLDS AND VELOCITY VALUES V4

mfr_cs4V4 = np.array(mfr_cs4V4)
mfr_cs6V4 = np.array(mfr_cs6V4)
mfr_cs8V4 = np.array(mfr_cs8V4)
mfr_cs10V4 = np.array(mfr_cs10V4)
mfr_cs12V4 = np.array(mfr_cs12V4)
mfr_cs15V4 = np.array(mfr_cs15V4)

V_cs4V4 = np.array(Velocity(mfr_cs4V4, rho, Acs_cs4V4))
V_cs6V4 = np.array(Velocity(mfr_cs6V4, rho, Acs_cs6V4))
V_cs8V4 = np.array(Velocity(mfr_cs8V4, rho, Acs_cs8V4))
V_cs10V4 = np.array(Velocity(mfr_cs10V4, rho, Acs_cs10V4))
V_cs12V4 = np.array(Velocity(mfr_cs12V4, rho, Acs_cs12V4))
V_cs15V4 = np.array(Velocity(mfr_cs15V4, rho, Acs_cs15V4))

Re_cs4_V4 = Reynolds2(mfr_cs4V4, Dh_cs4V4, Acs_cs4V4, mu)
Re_cs6_V4 = Reynolds2(mfr_cs6V4, Dh_cs6V4, Acs_cs6V4, mu)
Re_cs8_V4 = Reynolds2(mfr_cs8V4, Dh_cs8V4, Acs_cs8V4, mu)
Re_cs10_V4 = Reynolds2(mfr_cs10V4, Dh_cs10V4, Acs_cs10V4, mu)
Re_cs12_V4 = Reynolds2(mfr_cs12V4, Dh_cs12V4, Acs_cs12V4, mu)
Re_cs15_V4 = Reynolds2(mfr_cs15V4, Dh_cs15V4, Acs_cs15V4, mu)


f_cs4V4 = ffactor(np.array(dp_cs4V4), Dh_cs4V4, Lf, rho, V_cs4V4)
f_cs6V4 = ffactor(np.array(dp_cs6V4), Dh_cs6V4, Lf, rho, V_cs6V4)
f_cs8V4 = ffactor(np.array(dp_cs8V4), Dh_cs8V4, Lf, rho, V_cs8V4)
f_cs10V4 = ffactor(np.array(dp_cs10V4), Dh_cs10V4, Lf, rho, V_cs10V4)
f_cs12V4 = ffactor(np.array(dp_cs12V4), Dh_cs12V4, Lf, rho, V_cs12V4)
f_cs15V4 = ffactor(np.array(dp_cs15V4), Dh_cs15V4, Lf, rho, V_cs15V4)

# %%
def Traces(x, y, name, color, symbol): #symbol = circle, square, diamond, cross, triangle-up, pentaon, hexagon, star
    trace = go.Scatter(
        x=x,
        y=y,
        name=name,
        mode='markers',
        marker=dict(
            size=15,
            color=color,
            symbol=symbol,  # Forma do marcador
            line=dict(
                width=2,
                color='Black'  # Cor da borda do marcador
            )
        )
    )
    return trace



def curves(trace, title, ytitle):

    fig = go.Figure(data = trace)

    fig.update_layout(
    font=dict(
    size=15),
    title={
        'text': title,
        'x': 0.5,
        'xanchor': 'center'
    },
    xaxis={
        'title': 'Reynolds',
        'showline': True,
        'showgrid': False,
        'zeroline': True,
        'zerolinecolor': 'black',
        'linecolor': 'black',
        'ticks': 'outside',
        'mirror': True
    },
    yaxis={
        'title': ytitle,
        'showline': True,
        'showgrid': False,
        'zeroline': True,
        'zerolinecolor': 'black',
        'linecolor': 'black',
        'ticks': 'outside',
        'mirror': True
    },
    plot_bgcolor='white',
    hovermode='closest',
    width=800,  # Largura do gráfico
    height=600  # Altura do gráfico
)
    
    pyo.plot(fig)

# %%
#a = Traces(Re_cs4_V3, abs_cs4V3, 'dp_cs4V3', 'red', 'circle')
b = Traces(Re_cs6_V3, abs_cs6V3, 'dp_cs6V3','red', 'circle')
c = Traces(Re_cs8_V3, abs_cs8V3, 'dp_cs8V3', 'green','circle')
d = Traces(Re_cs10_V3, abs_cs10V3, 'dp_cs10V3', 'blue','circle')
e = Traces(Re_cs12_V3, abs_cs12V3, 'dp_cs12V3', 'cyan','circle')


traces = [b,c,d,e]

curves(traces, 'dP x Reynolds', 'dP (Pa)')

# %%
#a = Traces(Re_cs4_V3, abs_cs4V3, 'dp_cs4V3', 'red', 'circle')
b = Traces(Re_cs6_V3, f_cs6V3, 'f_cs6V3','red', 'circle')
c = Traces(Re_cs8_V3, f_cs8V3, 'f_cs8V3', 'green','circle')
d = Traces(Re_cs10_V3, f_cs10V3, 'f_cs10V3', 'blue','circle')
e = Traces(Re_cs12_V3, f_cs12V3, 'f_cs12V3', 'cyan','circle')

traces = [b,c,d,e]

curves(traces, 'f x Reynolds', 'f')

# %%
a = Traces(f_cs6V3, np.array(stdp[1]*7), 'f_cs6V3', 'red', 'circle')
b = Traces(f_cs8V3, np.array(stdp[2]*7), 'f_cs8V3', 'green', 'circle')
c = Traces(f_cs10V3, np.array(stdp[3]*7), 'f_cs10V3', 'blue', 'circle')
d = Traces(f_cs12V3, np.array(stdp[4]*7), 'f_cs12V3', 'cyan', 'circle')

traces = [a,b,c,d]

curves(traces, 'f x Reynolds', 'f')

# %%
import numpy as np
import plotly.graph_objs as go
import plotly.offline as pyo


# Define os traços
trace1 = go.Scatter3d(x=Re_cs6_V3, y=f_cs6V3, z=[stdp[1]]*len(Re_cs6_V3), mode='markers', name='Cs6_V3')
trace2 = go.Scatter3d(x=Re_cs8_V3, y=f_cs8V3, z=[stdp[2]]*len(Re_cs8_V3), mode='markers', name='Cs8_V3')
trace3 = go.Scatter3d(x=Re_cs10_V3, y=f_cs10V3, z=[stdp[3]]*len(Re_cs10_V3), mode='markers', name='Cs10_V3')
trace4 = go.Scatter3d(x=Re_cs12_V3, y=f_cs12V3, z=[stdp[4]]*len(Re_cs12_V3), mode='markers', name='Cs12_V4')



# Combina os traços e a superfície em uma única figura
fig = go.Figure(data=[trace1, trace2, trace3, trace4])

# Atualiza o layout
fig.update_layout(
    font=dict(size=15),
    title={
        'text': 'Scatter 3D Reynolds x f x Standard Porosity',
        'x': 0.5,
        'xanchor': 'center'
    },
    scene=dict(
        xaxis=dict(
            title='Reynolds',
            showline=True,
            showgrid=True,
            zeroline=True,
            zerolinecolor='black',
            linecolor='black',
            ticks='outside',
            mirror=True
        ),
        yaxis=dict(
            title='f',
            showline=True,
            showgrid=True,
            zeroline=True,
            zerolinecolor='black',
            linecolor='black',
            ticks='outside',
            mirror=True
        ),
        zaxis=dict(
            title='Standard Porosity',
            showline=True,
            showgrid=True,
            zeroline=True,
            zerolinecolor='black',
            linecolor='black',
            ticks='outside',
            mirror=True
        )
    ),
    plot_bgcolor='white',
    hovermode='closest',
    width=1000,  # Largura do gráfico
    height=800  # Altura do gráfico
)

# Mostra a figura
pyo.plot(fig)

# %%
dfx = [mfr_cs10V1]
print(dfx)
