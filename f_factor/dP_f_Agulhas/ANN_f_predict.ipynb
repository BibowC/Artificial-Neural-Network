# %%
import pandas as pd
import os
import numpy as np
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle

# Import data
file_name = 'fxReynoldsV3.xlsx'
file_path = os.path.join(os.getcwd(), file_name)

ANNDF = pd.read_excel(file_path)

# Prepare data
X = ANNDF.iloc[:, [1, 3]].values
Y = ANNDF.iloc[:, 2].values.reshape(-1, 1)

X, Y = shuffle(X, Y)

xtrain, xtest, ytrain, ytest = train_test_split(X, Y, train_size=0.75)  # 30% for testing and shuffle

scalerx = StandardScaler()
scalery = StandardScaler()

Xtrain = scalerx.fit_transform(xtrain)
Ytrain = scalery.fit_transform(ytrain)

# Define the MLPRegressor
mlp = MLPRegressor(max_iter=5000)

# Define parameter grid for GridSearchCV
nneurons = [1, 2, 4, 8, 16, 32, 64, 128]
parameters = {'hidden_layer_sizes': [],
              'activation': ['relu', 'tanh', 'logistic'],
              'solver': ['adam']
}

# Generate parameter combinations for hidden_layer_sizes
for n in nneurons:
    parameters['hidden_layer_sizes'].append((n,))

for n1 in nneurons:
    for n2 in nneurons:
        parameters['hidden_layer_sizes'].append((n1, n2))


# KFold cross-validation setup
kf = KFold(n_splits=10, shuffle=True)

# Applying GridSearchCV to train the model
gsearchcv = GridSearchCV(estimator=mlp, param_grid=parameters, cv=kf, verbose=2)
gsearchcv.fit(Xtrain, Ytrain.ravel())

# Define best score and parameters based on R²
bestac = gsearchcv.best_score_ * 100  # Convert to percentage
bestparam = gsearchcv.best_params_

print('Best Accuracy: {:.2f} %'.format(bestac))
print('Best Parameters:', bestparam)

# Define ranges for Re and Stdp
Re_vals = np.linspace(200, 8000, 50)  # Reynolds values from 200 to 8000
Stdp_vals = np.linspace(0.3326, 0.4331, 50)  # Stdp values from 0.3326 to 0.4331

# Create a grid of Re and Stdp
Re_grid, Stdp_grid = np.meshgrid(Re_vals, Stdp_vals)
grid_points = np.c_[Re_grid.ravel(), Stdp_grid.ravel()]

# Predict 'f' values using ANN on grid points
f_pred_scaled = gsearchcv.predict(scalerx.transform(grid_points))
f_pred = scalery.inverse_transform(f_pred_scaled.reshape(-1, 1))
f_pred_grid = f_pred.reshape(Re_grid.shape)

# Example prediction for a specific input
input_data = np.array([[1843, 0.4331]])

# Transform input data using the trained scaler
input_data_scaled = scalerx.transform(input_data)

# Make prediction with the trained model
predicted_scaled = gsearchcv.predict(input_data_scaled)

# Inverse transform the output scaling
predicted = scalery.inverse_transform(predicted_scaled.reshape(-1, 1))

# Prepare test data for prediction
Xtest_scaled = scalerx.transform(xtest)

ypred = gsearchcv.predict(Xtest_scaled).reshape(-1, 1)

ypred_or = scalery.inverse_transform(ypred)

# Display the result
print('Predicted value for [1843, 0.4331]:', predicted[0][0])
# Out:
# Fitting 10 folds for each of 216 candidates, totalling 2160 fits
# [CV] END activation=relu, hidden_layer_sizes=(1,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1,), solver=adam; total time=   0.3s
# [CV] END activation=relu, hidden_layer_sizes=(1,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1,), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(1,), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(1,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1,), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(1,), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(1,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1,), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(2,), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(2,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2,), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(2,), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(2,), solver=adam; total time=   0.3s
# [CV] END activation=relu, hidden_layer_sizes=(2,), solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=(2,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2,), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(4,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4,), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(4,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(64,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(64,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(64,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(64,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(64,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(64,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(64,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(64,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(64,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(64,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(128,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(128,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(128,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(128,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(128,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(128,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(128,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(128,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(128,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(128,), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 1), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 1), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(1, 1), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 1), solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=(1, 1), solver=adam; total time=   0.3s
# [CV] END activation=relu, hidden_layer_sizes=(1, 1), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(1, 1), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 1), solver=adam; total time=   0.3s
# [CV] END activation=relu, hidden_layer_sizes=(1, 1), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 1), solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=(1, 2), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(1, 2), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(1, 2), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(1, 2), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 2), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 2), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(1, 2), solver=adam; total time=   0.4s
# [CV] END activation=relu, hidden_layer_sizes=(1, 2), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 2), solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=(1, 2), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(1, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 4), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(1, 4), solver=adam; total time=   0.3s
# [CV] END activation=relu, hidden_layer_sizes=(1, 4), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(1, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 4), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(1, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 8), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(1, 8), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(1, 8), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(1, 8), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(1, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 16), solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=(1, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 16), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(1, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 32), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(1, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 64), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(1, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(1, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 1), solver=adam; total time=   0.3s
# [CV] END activation=relu, hidden_layer_sizes=(2, 1), solver=adam; total time=   0.3s
# [CV] END activation=relu, hidden_layer_sizes=(2, 1), solver=adam; total time=   0.3s
# [CV] END activation=relu, hidden_layer_sizes=(2, 1), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 1), solver=adam; total time=   0.3s
# [CV] END activation=relu, hidden_layer_sizes=(2, 1), solver=adam; total time=   0.6s
# [CV] END activation=relu, hidden_layer_sizes=(2, 1), solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=(2, 1), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 1), solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=(2, 1), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 2), solver=adam; total time=   0.3s
# [CV] END activation=relu, hidden_layer_sizes=(2, 2), solver=adam; total time=   0.8s
# [CV] END activation=relu, hidden_layer_sizes=(2, 2), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(2, 2), solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=(2, 2), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 2), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(2, 2), solver=adam; total time=   0.4s
# [CV] END activation=relu, hidden_layer_sizes=(2, 2), solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=(2, 2), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 2), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(2, 4), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(2, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 4), solver=adam; total time=   0.3s
# [CV] END activation=relu, hidden_layer_sizes=(2, 4), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(2, 4), solver=adam; total time=   0.5s
# [CV] END activation=relu, hidden_layer_sizes=(2, 4), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(2, 4), solver=adam; total time=   0.3s
# [CV] END activation=relu, hidden_layer_sizes=(2, 4), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(2, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 8), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(2, 8), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(2, 8), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(2, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 8), solver=adam; total time=   0.3s
# [CV] END activation=relu, hidden_layer_sizes=(2, 8), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(2, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 16), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(2, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 32), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(2, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 32), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(2, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 128), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(2, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(2, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 1), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(4, 1), solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=(4, 1), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(4, 1), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 1), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(4, 1), solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=(4, 1), solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=(4, 1), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(4, 1), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(4, 1), solver=adam; total time=   0.3s
# [CV] END activation=relu, hidden_layer_sizes=(4, 2), solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=(4, 2), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 2), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 2), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 2), solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=(4, 2), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(4, 2), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 2), solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=(4, 2), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 2), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(4, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 4), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(4, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 4), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(4, 4), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(4, 4), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(4, 8), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(4, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 8), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(4, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(4, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 1), solver=adam; total time=   0.5s
# [CV] END activation=relu, hidden_layer_sizes=(8, 1), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 1), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 1), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 1), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 1), solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=(8, 1), solver=adam; total time=   0.3s
# [CV] END activation=relu, hidden_layer_sizes=(8, 1), solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=(8, 1), solver=adam; total time=   0.4s
# [CV] END activation=relu, hidden_layer_sizes=(8, 1), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(8, 2), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 2), solver=adam; total time=   0.4s
# [CV] END activation=relu, hidden_layer_sizes=(8, 2), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(8, 2), solver=adam; total time=   0.4s
# [CV] END activation=relu, hidden_layer_sizes=(8, 2), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 2), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 2), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 2), solver=adam; total time=   0.4s
# [CV] END activation=relu, hidden_layer_sizes=(8, 2), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 2), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 8), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(8, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(8, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 1), solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=(16, 1), solver=adam; total time=   0.5s
# [CV] END activation=relu, hidden_layer_sizes=(16, 1), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 1), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 1), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 1), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(16, 1), solver=adam; total time=   0.3s
# [CV] END activation=relu, hidden_layer_sizes=(16, 1), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 1), solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=(16, 1), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 2), solver=adam; total time=   0.3s
# [CV] END activation=relu, hidden_layer_sizes=(16, 2), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 2), solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=(16, 2), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 2), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 2), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 2), solver=adam; total time=   0.3s
# [CV] END activation=relu, hidden_layer_sizes=(16, 2), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(16, 2), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 2), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 4), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(16, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(16, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 1), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 1), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 1), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 1), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 1), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 1), solver=adam; total time=   0.5s
# [CV] END activation=relu, hidden_layer_sizes=(32, 1), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 1), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(32, 1), solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=(32, 1), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 2), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 2), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 2), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 2), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 2), solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=(32, 2), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(32, 2), solver=adam; total time=   0.6s
# [CV] END activation=relu, hidden_layer_sizes=(32, 2), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 2), solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=(32, 2), solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=(32, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 4), solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(32, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 4), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 8), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 16), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 32), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 64), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 128), solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(32, 128), solver=adam; total time=   0.0s
# ...
# [CV] END activation=logistic, hidden_layer_sizes=(32, 64), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(32, 64), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(32, 64), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(32, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(32, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(32, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(32, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(32, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(32, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(32, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(32, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(32, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(32, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 1), solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 1), solver=adam; total time=   0.3s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 1), solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 1), solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 1), solver=adam; total time=   0.4s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 1), solver=adam; total time=   0.4s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 1), solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 1), solver=adam; total time=   0.3s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 1), solver=adam; total time=   0.3s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 1), solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 2), solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 2), solver=adam; total time=   0.4s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 2), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 2), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 2), solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 2), solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 2), solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 2), solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 2), solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 2), solver=adam; total time=   0.4s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 4), solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 4), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 4), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 4), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 4), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 4), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 4), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 4), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 4), solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 4), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 8), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 8), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 8), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 8), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 8), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 8), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 8), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 8), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 8), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 8), solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 16), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 16), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 16), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 16), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 16), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 16), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 16), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 16), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 16), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 16), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 32), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 32), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 32), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 32), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 32), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 32), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 32), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 32), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 32), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 32), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 64), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 64), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 64), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 64), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 64), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 64), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 64), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 64), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 64), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 64), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(64, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 1), solver=adam; total time=   0.3s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 1), solver=adam; total time=   0.5s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 1), solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 1), solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 1), solver=adam; total time=   0.5s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 1), solver=adam; total time=   0.5s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 1), solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 1), solver=adam; total time=   0.4s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 1), solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 1), solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 2), solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 2), solver=adam; total time=   0.4s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 2), solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 2), solver=adam; total time=   0.4s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 2), solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 2), solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 2), solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 2), solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 2), solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 2), solver=adam; total time=   0.4s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 4), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 4), solver=adam; total time=   0.3s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 4), solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 4), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 4), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 4), solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 4), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 4), solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 4), solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 4), solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 8), solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 8), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 8), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 8), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 8), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 8), solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 8), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 8), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 8), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 8), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 16), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 16), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 16), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 16), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 16), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 16), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 16), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 16), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 16), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 16), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 32), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 32), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 32), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 32), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 32), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 32), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 32), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 32), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 32), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 32), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 64), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 64), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 64), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 64), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 64), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 64), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 64), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 64), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 64), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 64), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 128), solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(128, 128), solver=adam; total time=   0.0s
# Best Accuracy: 96.38 %
# Best Parameters: {'activation': 'relu', 'hidden_layer_sizes': (16, 128), 'solver': 'adam'}
# Predicted value for [1843, 0.4331]: 0.5087930149601371

# %%
nneurons = list([1,2,4,8,16,32,64,128])
parameters['hidden_layer_sizes'] = list()
print(parameters['hidden_layer_sizes'])
for n in nneurons:
    parameters['hidden_layer_sizes'].append(n)

for n1 in nneurons:
    for n2 in nneurons:
        parameters['hidden_layer_sizes'].append(list([n1,n2]))

print(parameters['hidden_layer_sizes'])
# Out:
# []
# [1, 2, 4, 8, 16, 32, 64, 128, [1, 1], [1, 2], [1, 4], [1, 8], [1, 16], [1, 32], [1, 64], [1, 128], [2, 1], [2, 2], [2, 4], [2, 8], [2, 16], [2, 32], [2, 64], [2, 128], [4, 1], [4, 2], [4, 4], [4, 8], [4, 16], [4, 32], [4, 64], [4, 128], [8, 1], [8, 2], [8, 4], [8, 8], [8, 16], [8, 32], [8, 64], [8, 128], [16, 1], [16, 2], [16, 4], [16, 8], [16, 16], [16, 32], [16, 64], [16, 128], [32, 1], [32, 2], [32, 4], [32, 8], [32, 16], [32, 32], [32, 64], [32, 128], [64, 1], [64, 2], [64, 4], [64, 8], [64, 16], [64, 32], [64, 64], [64, 128], [128, 1], [128, 2], [128, 4], [128, 8], [128, 16], [128, 32], [128, 64], [128, 128]]

# %%
def cor1(Re):
    f = 2.344 * np.power(Re,-0.081) #correlação kaixin yan  300 < RE <3100
    return f

def cor2(Re):
    f = 2.765 * np.power(Re,-0.166) #correlação kaixin yan  300 < RE <3100
    return f

Recor1 = np.linspace(300,3100,15)
stpkyan = [0.3745] * len(Recor1)

# %%
print(xtest[:,1])
# Out:
# [0.2992 0.4162 0.3795 0.4162 0.4331 0.3745 0.3326 0.2992 0.4331 0.3745
#  0.3996 0.3494 0.3494 0.4162 0.2992 0.4162 0.4197 0.3745 0.4197 0.4197
#  0.3996 0.3996 0.3494 0.4162 0.3326 0.3996 0.366  0.4331 0.3996 0.3996
#  0.3795 0.366  0.4162 0.2992 0.2992 0.4162 0.3996 0.4331 0.3996 0.366
#  0.3745 0.4331 0.4331 0.3795 0.2992 0.3494 0.3494]

# %%
import numpy as np
import plotly.graph_objs as go
import plotly.offline as pyo



# Definir os intervalos para Re e Stdp
Re_vals = np.linspace(200, 8000, 100)  # Valores de Reynolds de 1000 a 8000
Stdp_vals = np.linspace(0.2992, 0.4331, 100)  # Valores de Stdp de 0.3326 a 0.4331

#ffc = 2.7753 + (-3.1833e-04)*Re_vals + (-7.3509e+00)*Stdp_vals + (1.1566e-08)*Re_vals^2 + (9.1489e-04)*Re_vals * Stdp_vals + (3.0968e+00)*Stdp_vals^2 + (-5.4668e-13)*Re_vals^3 + (-2.9617e-09)*Re_vals^2 * Stdp_vals + (-7.7045e-04)*Re_vals * Stdp_vals^2 + (6.7924e+00)*Stdp_vals^3

# Criar uma grade de Re e Stdp
Re_grid, Stdp_grid = np.meshgrid(Re_vals, Stdp_vals)
grid_points = np.c_[Re_grid.ravel(), Stdp_grid.ravel()]

# Prever os valores de 'f' usando a ANN nos pontos da grade
f_pred_scaled = gsearchcv.predict(scalerx.transform(grid_points))
f_pred = scalery.inverse_transform(f_pred_scaled.reshape(-1, 1))
f_pred_grid = f_pred.reshape(Re_grid.shape)

# Calcular a superfície usando a fórmula fornecida
f_formula = (4.3059 / np.log(Re_grid + 3.1918)) + ((0.30649 / Stdp_grid) - 0.80937)

# Criar o gráfico 3D para os resultados da ANN com contornos
surface_ann = go.Surface(
    x=Re_grid, y=Stdp_grid, z=f_pred_grid, 
    colorscale='Viridis',
    name='Superfície ANN',
    colorbar=dict(title='ANN f', len=0.5, x=0.9),
    contours={
        "z": {
            "show": True,
            "start": np.min(f_pred_grid),
            "end": np.max(f_pred_grid),
            "size": (np.max(f_pred_grid) - np.min(f_pred_grid)) / 20,  # Ajustar o espaçamento dos contornos
            "color": "black",
        }
    }
)

# Criar o gráfico 3D para a fórmula fornecida com contornos
surface_formula = go.Surface(
    x=Re_grid, y=Stdp_grid, z=f_formula, 
    colorscale='Plasma',
    name='Superfície Fórmula',
    opacity=0.7,
    colorbar=dict(title='Fórmula f', len=0.5, x=1.05),
    contours={
        "z": {
            "show": True,
            "start": np.min(f_formula),
            "end": np.max(f_formula),
            "size": (np.max(f_formula) - np.min(f_formula)) / 20,
            "color": "black",
        }
    }
)

# Scatter plot dos valores originais
scatter_cor = go.Scatter3d(
    x=Recor1,  # Valores de Reynolds
    y=stpkyan,  # Valores de Stdp
    z=cor2(Recor1),  # Valores de 'f'
    mode='markers',
    marker=dict(size=5, color='black'),
    name='Kaixin Yan et. al (Polished)'
)

scatter_cor2 = go.Scatter3d(
    x=xtest[:,0],  # Valores de Reynolds
    y=xtest[:,1],  # Valores de Stdp
    z=ypred_or.flatten(),  # Valores de 'f'
    mode='markers',
    marker=dict(size=5, color='red', symbol = 'diamond'),
    name='Predict / Validation'
)



# Scatter plot dos valores originais
scatter_data = go.Scatter3d(
    x=ANNDF.iloc[:, 0].values,  # Valores de Reynolds
    y=ANNDF.iloc[:, 2].values,  # Valores de Stdp
    z=ANNDF.iloc[:, 1].values,  # Valores de 'f'
    mode='markers',
    marker=dict(size=5, color='red'),
    name='Valores Originais'
)

# Definir o layout do gráfico
layout = go.Layout(
    title='Superfície de Resultados da ANN e da Fórmula com Valores Originais',
    scene=dict(
        xaxis=dict(title='Reynolds Number (Re)', backgroundcolor='white', gridcolor='lightgrey'),
        yaxis=dict(title='Stdp', backgroundcolor='white', gridcolor='lightgrey'),
        zaxis=dict(title='f', backgroundcolor='white', gridcolor='lightgrey'),
        bgcolor='white'
    ),
    paper_bgcolor='white',
    plot_bgcolor='white',
    showlegend=True
)

# Criar a figura com ambas as superfícies e o scatter plot
fig = go.Figure(data=[surface_ann, scatter_cor, scatter_cor2], layout=layout)

# Mostrar o gráfico
pyo.plot(fig)
# Out:
# 'temp-plot.html'

# %%
import numpy as np
import plotly.graph_objs as go
import plotly.io as pio

# Definir os intervalos para Re e Stdp
Re_vals = np.linspace(1000, 8000, 100)  # Valores de Reynolds de 1000 a 8000
Stdp_vals = np.linspace(0.3326, 0.4331, 100)  # Valores de Stdp de 0.3326 a 0.4331

# Criar uma grade de Re e Stdp
Re_grid, Stdp_grid = np.meshgrid(Re_vals, Stdp_vals)

# Calcular a superfície usando a fórmula fornecida
f_formula = (4.3059 / np.log(Re_grid + 3.1918)) + ((0.30649 / Stdp_grid) - 0.80937)

# Criar o gráfico de contorno 2D para a fórmula fornecida
contour_formula = go.Contour(
    z=f_formula, 
    x=Re_vals, 
    y=Stdp_vals, 
    colorscale='Viridis', 
    name='Fórmula Contour',
    colorbar=dict(title='f')
)

# Definir o layout do gráfico
layout_formula = go.Layout(
    title='f Contour (Formula)',
    xaxis=dict(title='Reynolds Number (Re)'),
    yaxis=dict(title='Stdp'),
    width=800,  # Largura da imagem
    height=600  # Altura da imagem
)

# Criar a figura com o gráfico de contorno da fórmula
fig_formula = go.Figure(data=[contour_formula], layout=layout_formula)

# Mostrar o gráfico
pio.show(fig_formula)

# %%
import numpy as np
import plotly.graph_objs as go
import plotly.io as pio

# Definir os intervalos para Re e Stdp
Re_vals = np.linspace(1000, 8000, 100)  # Valores de Reynolds de 1000 a 8000
Stdp_vals = np.linspace(0.3326, 0.4331, 100)  # Valores de Stdp de 0.3326 a 0.4331

# Criar uma grade de Re e Stdp
Re_grid, Stdp_grid = np.meshgrid(Re_vals, Stdp_vals)
grid_points = np.c_[Re_grid.ravel(), Stdp_grid.ravel()]

# Prever os valores de 'f' usando a ANN nos pontos da grade
f_pred_scaled = gsearchcv.predict(scalerx.transform(grid_points))
f_pred = scalery.inverse_transform(f_pred_scaled.reshape(-1, 1))
f_pred_grid = f_pred.reshape(Re_grid.shape)

# Criar o gráfico de contorno 2D para os resultados da ANN
contour_ann = go.Contour(
    z=f_pred_grid, 
    x=Re_vals, 
    y=Stdp_vals, 
    colorscale='Viridis', 
    name='ANN Contour',
    colorbar=dict(title='ANN f')
)

# Scatter plot dos valores originais
scatter_data = go.Scatter(
    x=ANNDF.iloc[:, 0].values,  # Valores de Reynolds
    y=ANNDF.iloc[:, 2].values,  # Valores de Stdp
    mode='markers',
    marker=dict(size=5, color='red'),
    name='Valores Originais'
)

# Definir o layout do gráfico
layout_ann = go.Layout(
    title='Contorno dos Resultados da ANN com Valores Originais',
    xaxis=dict(title='Reynolds Number (Re)'),
    yaxis=dict(title='Stdp'),
    width=800,  # Largura da imagem
    height=600  # Altura da imagem
)

# Criar a figura com o gráfico de contorno da ANN e o scatter plot dos valores originais
fig_ann = go.Figure(data=[contour_ann], layout=layout_ann)

# Mostrar o gráfico
pio.show(fig_ann)
